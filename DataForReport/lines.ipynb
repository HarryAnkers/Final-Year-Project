# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
filepath = './../Src/test_files/Process_10/log_files/lineslog.txt'
lines = []
with open(filepath) as fp:
   for line in fp:
       lines.append(int(line))

# %%
print(np.mean(lines))
print(np.std(lines))
print(scipy.stats.skew(lines))
plt.hist(lines, bins=50)
plt.xlabel("lines")
plt.ylabel("frequency")
plt.title("done")
plt.grid()
plt.savefig('lines-file-50bin.png', dpi=500)
plt.show()
# Out:
# 150.51790633608815
# 154.4230766238119
# 1.444916319927255
